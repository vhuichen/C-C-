# %%
pip install zigzag
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 1.2 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Obtaining dependency information for Cython<0.30,>=0.29 from https://files.pythonhosted.org/packages/7e/26/9d8de10005fedb1eceabe713348d43bae1dbab1786042ca0751a2e2b0f8c/Cython-0.29.37-py2.py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 989.5/989.5 kB 3.1 MB/s eta 0:00:00a 0:00:01
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for zigzag (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [147 lines of output]
#       /private/var/folders/w7/j3n3qwq96dbgf9dfwmzg80n80000gn/T/pip-install-vml35hf4/zigzag_6cdd636a16654a8ea3a383a55901d735/build.py:4: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
# ...
